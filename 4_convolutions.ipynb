# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.544826
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.553413
# Minibatch accuracy: 43.8%
# Validation accuracy: 58.8%
# Minibatch loss at step 100: 1.045258
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.9%
# Minibatch loss at step 150: 1.027569
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.1%
# Minibatch loss at step 200: 0.838655
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.1%
# Minibatch loss at step 250: 0.622110
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 300: 0.345594
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 350: 1.092210
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.2%
# Minibatch loss at step 400: 1.528940
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 450: 0.480612
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 500: 1.090035
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.6%
# Minibatch loss at step 550: 0.947511
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 600: 0.604114
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 650: 0.461142
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 700: 0.383259
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 750: 0.733497
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.7%
# Minibatch loss at step 800: 0.783506
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 850: 1.444880
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 900: 0.179887
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 950: 0.282453
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000: 0.712241
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Test accuracy: 89.9%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases) 
    hidden = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=None)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME', name=None)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.523956
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 0.783304
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.5%
# Minibatch loss at step 100: 0.980561
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.5%
# Minibatch loss at step 150: 0.704124
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 200: 0.808490
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 250: 0.564238
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 300: 0.404678
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 350: 1.206730
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 400: 1.453463
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 450: 0.561371
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 500: 0.662707
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 550: 0.539272
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 600: 0.630398
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 650: 0.539051
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 700: 0.284052
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 750: 0.557090
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 800: 0.803878
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.5%
# Minibatch loss at step 850: 1.102796
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 900: 0.064028
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 950: 0.181414
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 1000: 0.671131
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 1050: 0.731866
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 1100: 0.503134
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 1150: 0.535913
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 1200: 0.302497
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 1250: 0.426166
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 1300: 0.641531
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 1350: 0.574324
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 1400: 0.335360
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 1450: 0.246286
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 1500: 0.046358
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 1550: 0.245941
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 1600: 0.339739
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 1650: 0.639810
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 1700: 0.610580
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 1750: 0.207099
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 1800: 0.987539
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 1850: 0.264523
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 1900: 0.159534
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 1950: 0.622236
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 2000: 0.156483
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 2050: 0.401390
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 2100: 0.280719
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 2150: 0.177336
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 2200: 0.747724
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 2250: 0.297445
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 2300: 0.366756
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2350: 0.628844
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 2400: 0.052247
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 2450: 0.494260
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.9%
# Minibatch loss at step 2500: 0.844677
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.5%
# Minibatch loss at step 2550: 0.408142
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 2600: 0.364614
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 2650: 0.981467
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 2700: 0.130861
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 2750: 0.610710
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 2800: 0.593434
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 2850: 0.312660
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 2900: 0.015816
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 2950: 0.199935
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 3000: 0.610382
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Test accuracy: 93.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 128
patch_size_1 = 5
patch_size_2 = 5
patch_size_3 = 5
depth1 = 6
depth2 = 16
depth3 = 120
pool_size_1 = 2
pool_size_2 = 2
stride_1 = 2
stride_2 = 2
dropout_1 = 0.75
dropout_2 = 0.5
num_hidden_1 = 84

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  global_step = tf.Variable(0, trainable=False)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size_1, patch_size_1, num_channels, depth1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size_2, patch_size_2, depth1, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [patch_size_3, patch_size_3, depth2, depth3], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[depth3]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth3, num_hidden_1], stddev=0.01))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden_1]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden_1, num_labels], stddev=0.01))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, dropout = True):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases) 
    hidden = tf.nn.max_pool(hidden, ksize=[1, pool_size_1, pool_size_1, 1], strides=[1, stride_1, stride_1, 1], padding='SAME', name=None)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    hidden = tf.nn.max_pool(hidden, ksize=[1, pool_size_2, pool_size_2, 1], strides=[1, stride_2, stride_2, 1], padding='SAME', name=None)
    conv = tf.nn.conv2d(hidden, layer3_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer3_biases)
    if dropout:
        hidden = tf.nn.dropout(hidden, dropout_1)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    if dropout:
        hidden = tf.nn.dropout(hidden, dropout_2)
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer. 
  optimizer = tf.train.AdamOptimizer(learning_rate = 0.001, beta1=0.9, beta2=0.999, epsilon=1e-8).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(model(tf_train_dataset, dropout=True))
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, dropout=False))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, dropout=False))

# %%
num_examples = np.shape(train_dataset)[0]
num_epochs = 6
num_steps = num_examples // batch_size * num_epochs

print("num examples = %d, num epochs = %d, num steps = %d" % (num_examples, num_epochs, num_steps))

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    indices = np.random.randint(0, train_labels.shape[0], batch_size)
    batch_data = train_dataset[indices, :, :, :]
    batch_labels = train_labels[indices, :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# num examples = 200000, num epochs = 6, num steps = 9372
# Initialized
# Minibatch loss at step 0: 2.322471
# Minibatch accuracy: 10.9%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.831691
# Minibatch accuracy: 34.4%
# Validation accuracy: 56.5%
# Minibatch loss at step 100: 1.317168
# Minibatch accuracy: 54.7%
# Validation accuracy: 75.9%
# Minibatch loss at step 150: 1.104513
# Minibatch accuracy: 58.6%
# Validation accuracy: 78.6%
# Minibatch loss at step 200: 1.063609
# Minibatch accuracy: 65.6%
# Validation accuracy: 80.6%
# Minibatch loss at step 250: 1.096082
# Minibatch accuracy: 64.1%
# Validation accuracy: 81.5%
# Minibatch loss at step 300: 0.961096
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 350: 0.591254
# Minibatch accuracy: 76.6%
# Validation accuracy: 83.5%
# Minibatch loss at step 400: 0.627385
# Minibatch accuracy: 77.3%
# Validation accuracy: 83.9%
# Minibatch loss at step 450: 0.636365
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 500: 0.799716
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.1%
# Minibatch loss at step 550: 0.575833
# Minibatch accuracy: 84.4%
# Validation accuracy: 85.6%
# Minibatch loss at step 600: 0.562952
# Minibatch accuracy: 76.6%
# Validation accuracy: 85.7%
# Minibatch loss at step 650: 0.543032
# Minibatch accuracy: 79.7%
# Validation accuracy: 86.1%
# Minibatch loss at step 700: 0.576733
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 750: 0.616577
# Minibatch accuracy: 82.0%
# Validation accuracy: 86.5%
# Minibatch loss at step 800: 0.644790
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 850: 0.585858
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 900: 0.454302
# Minibatch accuracy: 88.3%
# Validation accuracy: 87.1%
# Minibatch loss at step 950: 0.581169
# Minibatch accuracy: 80.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 1000: 0.577864
# Minibatch accuracy: 85.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 1050: 0.565089
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.9%
# Minibatch loss at step 1100: 0.384547
# Minibatch accuracy: 89.1%
# Validation accuracy: 87.8%
# Minibatch loss at step 1150: 0.393785
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.0%
# Minibatch loss at step 1200: 0.352150
# Minibatch accuracy: 90.6%
# Validation accuracy: 88.5%
# Minibatch loss at step 1250: 0.365415
# Minibatch accuracy: 89.1%
# Validation accuracy: 88.2%
# Minibatch loss at step 1300: 0.498968
# Minibatch accuracy: 83.6%
# Validation accuracy: 88.4%
# Minibatch loss at step 1350: 0.560649
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Minibatch loss at step 1400: 0.615214
# Minibatch accuracy: 82.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 1450: 0.466012
# Minibatch accuracy: 88.3%
# Validation accuracy: 88.8%
# Minibatch loss at step 1500: 0.389943
# Minibatch accuracy: 86.7%
# Validation accuracy: 88.8%
# Minibatch loss at step 1550: 0.506668
# Minibatch accuracy: 84.4%
# Validation accuracy: 88.9%
# Minibatch loss at step 1600: 0.535556
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.3%
# Minibatch loss at step 1650: 0.371868
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.0%
# Minibatch loss at step 1700: 0.335865
# Minibatch accuracy: 89.8%
# Validation accuracy: 89.2%
# Minibatch loss at step 1750: 0.385583
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.2%
# Minibatch loss at step 1800: 0.451055
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.2%
# Minibatch loss at step 1850: 0.368464
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.5%
# Minibatch loss at step 1900: 0.512069
# Minibatch accuracy: 85.9%
# Validation accuracy: 89.3%
# Minibatch loss at step 1950: 0.268548
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.4%
# Minibatch loss at step 2000: 0.520734
# Minibatch accuracy: 82.8%
# Validation accuracy: 89.3%
# Minibatch loss at step 2050: 0.395765
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.6%
# Minibatch loss at step 2100: 0.359274
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
# Minibatch loss at step 2150: 0.350293
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.0%
# Minibatch loss at step 2200: 0.250852
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Minibatch loss at step 2250: 0.321540
# Minibatch accuracy: 86.7%
# Validation accuracy: 89.9%
# Minibatch loss at step 2300: 0.340920
# Minibatch accuracy: 85.2%
# Validation accuracy: 89.8%
# Minibatch loss at step 2350: 0.324895
# Minibatch accuracy: 89.1%
# Validation accuracy: 89.8%
# Minibatch loss at step 2400: 0.346155
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.0%
# Minibatch loss at step 2450: 0.198778
# Minibatch accuracy: 94.5%
# Validation accuracy: 90.0%
# Minibatch loss at step 2500: 0.468111
# Minibatch accuracy: 85.2%
# Validation accuracy: 90.2%
# Minibatch loss at step 2550: 0.338741
# Minibatch accuracy: 91.4%
# Validation accuracy: 89.8%
# Minibatch loss at step 2600: 0.300432
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 2650: 0.381240
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.2%
# Minibatch loss at step 2700: 0.398279
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 2750: 0.395858
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 2800: 0.445849
# Minibatch accuracy: 83.6%
# Validation accuracy: 90.2%
# Minibatch loss at step 2850: 0.296429
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.5%
# Minibatch loss at step 2900: 0.272955
# Minibatch accuracy: 88.3%
# Validation accuracy: 90.4%
# Minibatch loss at step 2950: 0.454384
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.6%
# Minibatch loss at step 3000: 0.358875
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.4%
# Minibatch loss at step 3050: 0.298560
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.4%
# Minibatch loss at step 3100: 0.645497
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.6%
# Minibatch loss at step 3150: 0.366128
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.6%
# Minibatch loss at step 3200: 0.482751
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Minibatch loss at step 3250: 0.347253
# Minibatch accuracy: 86.7%
# Validation accuracy: 90.6%
# Minibatch loss at step 3300: 0.279957
# Minibatch accuracy: 92.2%
# Validation accuracy: 90.4%
# Minibatch loss at step 3350: 0.340082
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.5%
# Minibatch loss at step 3400: 0.325949
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 3450: 0.520873
# Minibatch accuracy: 82.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 3500: 0.308176
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.7%
# Minibatch loss at step 3550: 0.244584
# Minibatch accuracy: 89.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 3600: 0.443649
# Minibatch accuracy: 85.9%
# Validation accuracy: 90.9%
# Minibatch loss at step 3650: 0.409067
# Minibatch accuracy: 90.6%
# Validation accuracy: 90.9%
# Minibatch loss at step 3700: 0.445822
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.1%
# Minibatch loss at step 3750: 0.222723
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
# Minibatch loss at step 3800: 0.339766
# Minibatch accuracy: 91.4%
# Validation accuracy: 90.9%
# Minibatch loss at step 3850: 0.371356
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.2%
# Minibatch loss at step 3900: 0.350112
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# Minibatch loss at step 3950: 0.348271
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.9%
# Minibatch loss at step 4000: 0.339754
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
# Minibatch loss at step 4050: 0.237967
# Minibatch accuracy: 93.0%
# Validation accuracy: 90.8%
# Minibatch loss at step 4100: 0.211972
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.2%
# Minibatch loss at step 4150: 0.348701
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.0%
# Minibatch loss at step 4200: 0.359015
# Minibatch accuracy: 89.1%
# Validation accuracy: 90.9%
# Minibatch loss at step 4250: 0.269190
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.1%
# Minibatch loss at step 4300: 0.318906
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 4350: 0.342937
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.4%
# Minibatch loss at step 4400: 0.395526
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 4450: 0.393109
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 4500: 0.292661
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.2%
# Minibatch loss at step 4550: 0.421349
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.0%
# Minibatch loss at step 4600: 0.397548
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.3%
# Minibatch loss at step 4650: 0.272336
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 4700: 0.692112
# Minibatch accuracy: 81.2%
# Validation accuracy: 91.3%
# Minibatch loss at step 4750: 0.388047
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 4800: 0.302386
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 4850: 0.328937
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.1%
# Minibatch loss at step 4900: 0.370808
# Minibatch accuracy: 86.7%
# Validation accuracy: 91.2%
# Minibatch loss at step 4950: 0.429303
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 5000: 0.430249
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 5050: 0.128188
# Minibatch accuracy: 96.9%
# Validation accuracy: 91.2%
# Minibatch loss at step 5100: 0.279365
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.2%
# Minibatch loss at step 5150: 0.250302
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 5200: 0.261881
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 5250: 0.210322
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.5%
# Minibatch loss at step 5300: 0.288708
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.4%
# Minibatch loss at step 5350: 0.266679
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 5400: 0.347314
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.4%
# Minibatch loss at step 5450: 0.218639
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.4%
# Minibatch loss at step 5500: 0.250706
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.4%
# Minibatch loss at step 5550: 0.323031
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 5600: 0.253017
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.3%
# Minibatch loss at step 5650: 0.204714
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 5700: 0.382360
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 5750: 0.331711
# Minibatch accuracy: 87.5%
# Validation accuracy: 91.5%
# Minibatch loss at step 5800: 0.232702
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.6%
# Minibatch loss at step 5850: 0.359934
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.5%
# Minibatch loss at step 5900: 0.241572
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.3%
# Minibatch loss at step 5950: 0.209193
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 6000: 0.333032
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.6%
# Minibatch loss at step 6050: 0.290254
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 6100: 0.207351
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.3%
# Minibatch loss at step 6150: 0.224863
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 6200: 0.214145
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 6250: 0.132651
# Minibatch accuracy: 96.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 6300: 0.483121
# Minibatch accuracy: 83.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 6350: 0.213017
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.7%
# Minibatch loss at step 6400: 0.345545
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 6450: 0.317961
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 6500: 0.395924
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.6%
# Minibatch loss at step 6550: 0.415831
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.7%
# Minibatch loss at step 6600: 0.337355
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 6650: 0.272698
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 6700: 0.193096
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 6750: 0.283518
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 6800: 0.264770
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 6850: 0.257900
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.7%
# Minibatch loss at step 6900: 0.434401
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 6950: 0.358910
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 7000: 0.281578
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.6%
# Minibatch loss at step 7050: 0.156960
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.6%
# Minibatch loss at step 7100: 0.382122
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.6%
# Minibatch loss at step 7150: 0.286098
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 7200: 0.427575
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 7250: 0.233595
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.8%
# Minibatch loss at step 7300: 0.358856
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 7350: 0.253852
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 7400: 0.345743
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 7450: 0.252650
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.7%
# Minibatch loss at step 7500: 0.252077
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.8%
# Minibatch loss at step 7550: 0.328207
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.9%
# Minibatch loss at step 7600: 0.278435
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 7650: 0.301043
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 7700: 0.266585
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.7%
# Minibatch loss at step 7750: 0.297470
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.5%
# Minibatch loss at step 7800: 0.294700
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.5%
# Minibatch loss at step 7850: 0.240566
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 7900: 0.329954
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.0%
# Minibatch loss at step 7950: 0.297585
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 8000: 0.317613
# Minibatch accuracy: 85.9%
# Validation accuracy: 91.9%
# Minibatch loss at step 8050: 0.227033
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 8100: 0.202615
# Minibatch accuracy: 93.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 8150: 0.308249
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.7%
# Minibatch loss at step 8200: 0.314789
# Minibatch accuracy: 88.3%
# Validation accuracy: 91.8%
# Minibatch loss at step 8250: 0.371768
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 8300: 0.283760
# Minibatch accuracy: 89.1%
# Validation accuracy: 91.7%
# Minibatch loss at step 8350: 0.254639
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 8400: 0.263574
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.4%
# Minibatch loss at step 8450: 0.329183
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.6%
# Minibatch loss at step 8500: 0.323485
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 8550: 0.184133
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 8600: 0.196648
# Minibatch accuracy: 94.5%
# Validation accuracy: 91.8%
# Minibatch loss at step 8650: 0.132707
# Minibatch accuracy: 96.1%
# Validation accuracy: 92.0%
# Minibatch loss at step 8700: 0.242951
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.8%
# Minibatch loss at step 8750: 0.259530
# Minibatch accuracy: 93.0%
# Validation accuracy: 91.9%
# Minibatch loss at step 8800: 0.326972
# Minibatch accuracy: 90.6%
# Validation accuracy: 91.9%
# Minibatch loss at step 8850: 0.283929
# Minibatch accuracy: 88.3%
# Validation accuracy: 92.0%
# Minibatch loss at step 8900: 0.349432
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.0%
# Minibatch loss at step 8950: 0.313354
# Minibatch accuracy: 91.4%
# Validation accuracy: 91.7%
# Minibatch loss at step 9000: 0.308320
# Minibatch accuracy: 89.8%
# Validation accuracy: 91.8%
# Minibatch loss at step 9050: 0.155547
# Minibatch accuracy: 95.3%
# Validation accuracy: 91.9%
# Minibatch loss at step 9100: 0.339770
# Minibatch accuracy: 90.6%
# Validation accuracy: 92.0%
# Minibatch loss at step 9150: 0.132814
# Minibatch accuracy: 96.9%
# Validation accuracy: 92.0%
# Minibatch loss at step 9200: 0.156934
# Minibatch accuracy: 94.5%
# Validation accuracy: 92.0%
# Minibatch loss at step 9250: 0.329034
# Minibatch accuracy: 89.8%
# Validation accuracy: 92.0%
# Minibatch loss at step 9300: 0.271998
# Minibatch accuracy: 92.2%
# Validation accuracy: 91.9%
# Minibatch loss at step 9350: 0.322681
# Minibatch accuracy: 92.2%
# Validation accuracy: 92.0%
# Test accuracy: 96.7%
