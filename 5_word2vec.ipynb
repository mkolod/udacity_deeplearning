# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

# %matplotlib inline

from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'term', 'anarchism', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.082829
# Nearest to about: warners, abkhazians, chromosomes, membered, wetlands, limp, erowid, ligaments,
# Nearest to four: closely, exterminating, johore, pinocchio, racquets, explosively, perpetrator, lcm,
# Nearest to their: chamber, coagulation, erecting, glucose, pronunciations, albigensian, cowper, hur,
# Nearest to it: mori, jarmusch, cromwell, collages, wagoner, czechoslovak, mjw, conjecture,
# Nearest to b: cato, riddle, catalogue, abstain, pb, rebate, fathoms, zoology,
# Nearest to are: bravo, aikido, kamenev, sousa, falsely, descartes, pituitary, modularity,
# Nearest to after: rsa, chieftains, foibles, triggers, solidarity, assigning, unparalleled, commissioned,
# Nearest to one: daugava, columbine, spielberg, groningen, mainly, chap, mutagenic, carpenter,
# Nearest to been: bull, formulas, refrigerants, memel, gere, cana, chemotherapeutic, understandings,
# Nearest to three: cauldron, volo, mexicana, blacki, vertically, wct, grbac, jehu,
# Nearest to and: curved, watering, komondor, adequate, faunal, diagnose, diodes, tortuous,
# Nearest to which: dryer, kora, pawn, peng, voyaging, ehud, jorkens, kirchhoff,
# Nearest to but: pools, striped, vicarious, touches, motley, dvds, monasteries, penchant,
# Nearest to many: opinion, grows, comorian, trevelyan, supplemented, oslo, ideologically, greed,
# Nearest to at: microphones, ronnie, employers, octavio, write, hander, luk, cytotoxic,
# Nearest to UNK: maintainers, chessboard, repay, imported, resulted, laga, repudiating, oyly,
# Average loss at step 2000: 4.355653
# Average loss at step 4000: 3.865131
# Average loss at step 6000: 3.789899
# Average loss at step 8000: 3.684128
# Average loss at step 10000: 3.610231
# Nearest to about: nubcake, doppler, wedded, abkhazians, warners, chromosomes, acadians, membered,
# Nearest to four: six, three, eight, seven, five, nine, two, zero,
# Nearest to their: his, its, hutcheson, the, some, necromancers, this, sawyer,
# Nearest to it: he, this, there, they, she, not, which, also,
# Nearest to b: schengen, sayyaf, catalogue, abstain, zoology, herg, d, riddle,
# Nearest to are: were, is, have, katharine, be, harpists, was, modularity,
# Nearest to after: in, broca, triggers, capo, solidarity, harms, ystok, nights,
# Nearest to one: two, six, three, four, eight, seven, five, chu,
# Nearest to been: was, homogenized, by, cana, refrigerants, be, bull, also,
# Nearest to three: five, seven, four, six, eight, two, nine, zero,
# Nearest to and: or, mah, who, in, s, sampler, reforms, but,
# Nearest to which: that, it, this, also, dryer, pawn, jorkens, zealot,
# Nearest to but: striped, corresponded, would, he, orton, vicarious, and, touches,
# Nearest to many: some, other, oxley, eos, opinion, emphatically, stingray, trevelyan,
# Nearest to at: in, on, microphones, of, with, ecowas, from, naval,
# Nearest to UNK: hyphenated, maintainers, dispensation, storage, enrolled, superlatives, enigma, sagan,
# Average loss at step 12000: 3.604723
# Average loss at step 14000: 3.565781
# Average loss at step 16000: 3.411084
# Average loss at step 18000: 3.457175
# Average loss at step 20000: 3.537478
# Nearest to about: wedded, nubcake, doppler, bureaucrats, abkhazians, warners, acadians, influenza,
# Nearest to four: six, three, five, eight, two, seven, nine, one,
# Nearest to their: his, its, the, her, them, some, these, heather,
# Nearest to it: he, this, there, they, she, which, not, grampus,
# Nearest to b: d, sayyaf, actor, german, schengen, player, nonfiction, french,
# Nearest to are: were, is, have, modularity, katharine, audita, reassert, scone,
# Nearest to after: when, harms, before, diplomas, triggers, at, latinate, capo,
# Nearest to one: two, four, six, three, eight, five, seven, nine,
# Nearest to been: be, was, become, homogenized, memel, cana, by, never,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to and: or, but, from, kalashnikov, in, teaches, barra, with,
# Nearest to which: this, that, also, who, it, but, there, what,
# Nearest to but: however, viceroy, though, which, that, would, although, and,
# Nearest to many: some, other, several, these, all, huntingford, eos, wrist,
# Nearest to at: in, on, maoist, after, from, with, repressed, for,
# Nearest to UNK: r, brig, ucl, troglodytes, trajan, cerberus, lieutenant, maintainers,
# Average loss at step 22000: 3.495716
# Average loss at step 24000: 3.490430
# Average loss at step 26000: 3.475468
# Average loss at step 28000: 3.477712
# Average loss at step 30000: 3.498513
# Nearest to about: galla, wedded, troupe, doppler, on, election, herse, oath,
# Nearest to four: five, six, eight, seven, three, nine, two, zero,
# Nearest to their: its, his, her, the, some, these, many, oceanography,
# Nearest to it: he, she, there, this, they, which, never, not,
# Nearest to b: d, sayyaf, schengen, player, malraux, soybeans, om, abad,
# Nearest to are: were, have, is, audita, be, modularity, these, those,
# Nearest to after: before, when, from, at, during, in, capo, broca,
# Nearest to one: two, seven, four, eight, three, six, five, nine,
# Nearest to been: become, be, was, were, already, ever, cater, memel,
# Nearest to three: four, five, seven, eight, two, six, zero, nine,
# Nearest to and: or, but, guitars, who, micronesian, in, haden, illegitimate,
# Nearest to which: this, that, also, it, but, who, what, these,
# Nearest to but: however, although, though, and, which, when, eighty, or,
# Nearest to many: some, several, these, other, various, all, most, their,
# Nearest to at: in, after, on, when, gamsakhurdia, henotheistic, naval, dewar,
# Nearest to UNK: overlord, enrolled, peasantry, confirmation, dispensation, telepathy, adequacy, yunnan,
# Average loss at step 32000: 3.499542
# Average loss at step 34000: 3.493390
# Average loss at step 36000: 3.454083
# Average loss at step 38000: 3.306426
# Average loss at step 40000: 3.428228
# Nearest to about: galla, wedded, on, aversion, troupe, acadians, ordinarily, challenged,
# Nearest to four: six, three, seven, eight, five, two, nine, one,
# Nearest to their: its, his, her, the, some, our, these, them,
# Nearest to it: he, she, there, this, which, they, tezuka, not,
# Nearest to b: d, UNK, r, driver, n, dweller, f, h,
# Nearest to are: were, have, is, be, hatchet, although, including, modularity,
# Nearest to after: before, during, when, while, kuwaiti, from, capo, leftists,
# Nearest to one: eight, six, seven, four, two, three, nine, five,
# Nearest to been: become, be, was, were, already, never, mush, ever,
# Nearest to three: four, five, six, two, seven, eight, nine, one,
# Nearest to and: or, but, sram, sampler, are, guitars, maeshowe, licinius,
# Nearest to which: that, this, also, who, it, often, what, these,
# Nearest to but: however, although, though, and, where, when, which, while,
# Nearest to many: some, several, these, various, most, both, all, huntingford,
# Nearest to at: on, in, during, for, pdpa, westchester, crowd, near,
# Nearest to UNK: b, d, shocks, snes, exterminate, corrado, mantle, engine,
# Average loss at step 42000: 3.437287
# Average loss at step 44000: 3.454406
# Average loss at step 46000: 3.447399
# Average loss at step 48000: 3.349972
# Average loss at step 50000: 3.381707
# Nearest to about: galla, aversion, troupe, acadians, handler, wedded, challenged, least,
# Nearest to four: seven, six, five, eight, three, nine, two, zero,
# Nearest to their: its, his, her, the, some, our, both, your,
# Nearest to it: he, she, there, this, they, not, actually, govt,
# Nearest to b: d, r, x, mane, n, dweller, wee, f,
# Nearest to are: were, is, have, modularity, these, reassert, was, be,
# Nearest to after: before, during, when, from, while, if, sees, starve,
# Nearest to one: seven, two, six, eight, four, nine, three, five,
# Nearest to been: become, be, were, was, already, mush, had, ever,
# Nearest to three: seven, four, six, five, eight, two, nine, one,
# Nearest to and: or, but, including, culinary, guitars, while, sweeps, chaining,
# Nearest to which: that, this, also, who, often, what, usually, these,
# Nearest to but: however, although, though, since, when, and, while, which,
# Nearest to many: some, several, these, various, most, both, all, other,
# Nearest to at: during, from, in, near, pdpa, before, seeming, around,
# Nearest to UNK: de, la, jekyll, mickey, dov, lictors, maintainers, scarecrow,
# Average loss at step 52000: 3.433133
# Average loss at step 54000: 3.428184
# Average loss at step 56000: 3.435578
# Average loss at step 58000: 3.393824
# Average loss at step 60000: 3.393585
# Nearest to about: galla, dimensional, aversion, handler, breakup, troupe, marcelo, over,
# Nearest to four: five, six, three, seven, eight, nine, zero, two,
# Nearest to their: its, his, her, the, our, your, some, whose,
# Nearest to it: he, there, she, this, they, what, which, not,
# Nearest to b: d, p, n, c, x, r, fads, gorilla,
# Nearest to are: were, is, have, including, modularity, these, be, although,
# Nearest to after: before, during, when, while, if, dever, from, capo,
# Nearest to one: eight, six, two, seven, four, nine, five, three,
# Nearest to been: become, be, was, were, had, already, mush, dowling,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to and: or, but, including, although, culinary, marc, qualifies, like,
# Nearest to which: that, this, what, who, usually, but, it, however,
# Nearest to but: however, although, and, though, which, since, while, than,
# Nearest to many: some, several, various, these, most, both, other, all,
# Nearest to at: in, during, near, pdpa, throughout, repressed, wrappings, cumbersome,
# Nearest to UNK: edgerton, elixir, diverse, carlos, amar, chagrin, dot, urbino,
# Average loss at step 62000: 3.240974
# Average loss at step 64000: 3.252027
# Average loss at step 66000: 3.396965
# Average loss at step 68000: 3.394515
# Average loss at step 70000: 3.354491
# Nearest to about: galla, on, aversion, handler, marcelo, sulfate, breakup, dimensional,
# Nearest to four: five, six, eight, three, seven, two, nine, zero,
# Nearest to their: its, his, her, the, our, your, some, whose,
# Nearest to it: he, she, there, this, they, still, which, what,
# Nearest to b: d, p, x, n, j, h, r, f,
# Nearest to are: were, is, have, including, modularity, while, be, these,
# Nearest to after: before, during, when, while, if, until, for, dever,
# Nearest to one: two, six, seven, five, eight, four, nine, three,
# Nearest to been: become, be, were, already, was, had, mush, come,
# Nearest to three: five, four, six, two, eight, seven, nine, zero,
# Nearest to and: or, but, while, like, lonesome, semivowel, toxicity, for,
# Nearest to which: that, this, what, but, usually, also, however, often,
# Nearest to but: however, although, though, and, which, outposts, while, than,
# Nearest to many: some, several, these, various, all, most, both, such,
# Nearest to at: during, near, in, before, radiocommunication, yama, rosen, on,
# Nearest to UNK: amar, grain, hangman, gazing, universitat, bidder, franca, rtf,
# Average loss at step 72000: 3.372245
# Average loss at step 74000: 3.347586
# Average loss at step 76000: 3.314905
# Average loss at step 78000: 3.351006
# Average loss at step 80000: 3.367905
# Nearest to about: galla, shrewsbury, handler, aversion, breakup, nubcake, timesharing, dimensional,
# Nearest to four: six, five, seven, three, eight, nine, two, zero,
# Nearest to their: its, his, her, your, our, some, cali, whose,
# Nearest to it: he, she, there, this, they, itself, still, we,
# Nearest to b: d, p, c, x, everest, f, h, r,
# Nearest to are: were, have, is, include, these, reassert, those, modularity,
# Nearest to after: before, during, when, while, though, if, until, in,
# Nearest to one: six, seven, two, eight, four, five, three, nine,
# Nearest to been: become, be, already, was, were, remained, mush, pohnpei,
# Nearest to three: six, four, five, seven, two, eight, nine, zero,
# Nearest to and: or, but, henson, quesada, while, sweeps, guitars, facilitates,
# Nearest to which: this, that, usually, also, what, often, but, sierpinski,
# Nearest to but: however, although, though, while, than, or, and, see,
# Nearest to many: some, several, these, various, most, both, numerous, few,
# Nearest to at: in, during, before, on, cheryl, rosen, around, nter,
# Nearest to UNK: universalists, pilsener, mcdonough, exterminate, singer, intervenes, hogg, guerilla,
# Average loss at step 82000: 3.408865
# Average loss at step 84000: 3.408161
# Average loss at step 86000: 3.389055
# Average loss at step 88000: 3.353934
# Average loss at step 90000: 3.363323
# Nearest to about: galla, aversion, nubcake, timesharing, marcelo, handler, shrewsbury, conceding,
# Nearest to four: five, seven, eight, three, six, two, nine, one,
# Nearest to their: its, his, her, our, your, cali, whose, the,
# Nearest to it: he, she, there, this, they, which, itself, often,
# Nearest to b: d, c, p, k, f, j, r, everest,
# Nearest to are: were, is, have, these, reassert, include, audita, hatchet,
# Nearest to after: before, during, when, while, until, without, for, if,
# Nearest to one: seven, four, eight, six, two, five, three, nine,
# Nearest to been: become, be, already, was, were, previously, remained, specially,
# Nearest to three: four, five, two, eight, seven, six, nine, zero,
# Nearest to and: or, but, while, including, chaining, lonergan, culinary, mermaid,
# Nearest to which: that, this, what, usually, but, also, often, it,
# Nearest to but: however, although, and, though, which, while, until, that,
# Nearest to many: some, several, these, various, most, both, all, numerous,
# Nearest to at: during, in, near, cheryl, before, on, expressionist, after,
# Nearest to UNK: www, canonised, faroes, deuteronomic, mah, ha, snipers, accountants,
# Average loss at step 92000: 3.397046
# Average loss at step 94000: 3.250411
# Average loss at step 96000: 3.356420
# Average loss at step 98000: 3.244819
# Average loss at step 100000: 3.356190
# Nearest to about: on, aversion, marcelo, galla, around, handler, least, confusion,
# Nearest to four: six, five, seven, eight, three, two, nine, zero,
# Nearest to their: its, his, her, your, our, the, cali, some,
# Nearest to it: he, she, this, there, they, which, tezuka, actually,
# Nearest to b: d, werke, soybeans, spar, tripod, c, redistribution, j,
# Nearest to are: were, have, these, those, include, is, modularity, audita,
# Nearest to after: before, when, during, without, despite, until, while, through,
# Nearest to one: two, four, seven, six, eight, five, nine, three,
# Nearest to been: become, already, be, mush, previously, ever, remained, was,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to and: or, but, while, guitars, although, like, however, including,
# Nearest to which: that, this, what, but, usually, actually, often, it,
# Nearest to but: however, although, and, though, which, while, where, occur,
# Nearest to many: some, several, these, various, those, numerous, most, all,
# Nearest to at: during, in, on, near, rosen, cheryl, until, after,
# Nearest to UNK: maintainers, chill, rw, da, yahya, renewable, canonised, exterminate,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# Generate data for CBOW

# %%
data_index = 0

def generate_batch_cbow(batch_size, cbow_window):
    global data_index
    num_el = 2 * cbow_window
    assert batch_size % num_el == 0
    batch = np.ndarray(shape=(batch_size, num_el), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * cbow_window + 1    
    for i in range(batch_size):
        curr_batch_idx = 0
        for j in range(0, num_el + 1):           
            if j != cbow_window: 
                batch[i][curr_batch_idx] = data[data_index] 
                curr_batch_idx = curr_batch_idx + 1
            else:
                labels[i][0] = data[data_index]
            data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]], "\n")

for cbow_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, cbow_window = cbow_window)
    print("context window: +/- %d words\n" % cbow_window)
    print("batch:\n", batch, "\n")
    print("labels:\n", labels, "\n\n")
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# context window: +/- 1 words
#
# batch:
#  [[ 5239    12]
#  [    6     2]
#  [ 3137    59]
#  [  156   742]
#  [  477   134]
#  [    1     2]
#  [    1   855]
#  [    3 15068]]
#
# labels:
#  [[ 3084]
#  [  195]
#  [   46]
#  [  128]
#  [10572]
#  [27549]
#  [  103]
#  [    1]]
#
#
# context window: +/- 2 words
#
# batch:
#  [[ 5239  3084     6   195]
#  [    2  3137    59   156]
#  [  128   742 10572   134]
#  [    1 27549     1   103]
#  [  855     3 15068     0]
#  [    2     1   855  3583]
#  [    1   195   191    59]
#  [    5     6   215     7]]
#
# labels:
#  [[   12]
#  [   46]
#  [  477]
#  [    2]
#  [    1]
#  [  151]
#  [   11]
#  [10742]]

# %% [markdown]
# Train CBOW Model

# %%
random.seed(1000)

batch_size = 128
num_sampled = 64 # 64

embedding_size = 128 # Dimension of the embedding vector.
cbow_window = 1 # How many words to consider left and right.
num_el = 2 * cbow_window
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 20 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_el])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    logits = tf.placeholder(tf.float32, shape=[batch_size, embedding_size])
        
    # Add all words in the context window for every example
    # to form a single embedding.
    for i in range(num_el):
        indices = train_dataset[:, i]
        label_indices = train_labels[:,0]
        embed = tf.nn.embedding_lookup(embeddings, indices)
        if i == 0:
            temp = tf.mul(embed, tf.nn.embedding_lookup(softmax_weights, label_indices))
        else:
            temp = temp + tf.mul(embed, tf.nn.embedding_lookup(softmax_weights, label_indices))
#         if i == num_el - 1:
#             temp /= num_el
        
    loss = tf.reduce_mean(
        # softmax_weights
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, temp,
                                   train_labels, num_sampled, vocabulary_size))   


    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    for step in xrange(num_steps):
        batch_data, batch_labels = generate_batch_cbow(
            batch_size, cbow_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 100 == 0: # 2000
            if step > 0:
                average_loss = average_loss / 1000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 1000 == 0: # 100
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 5 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
        final_embeddings = normalized_embeddings.eval()
# Out:
# Average loss at step 0: 202.185902
# Nearest to however: solzhenitsyn, ferrous, consecrate, indicating, bum,
# Nearest to these: ct, refurbishment, purer, delicacies, gions,
# Nearest to nine: bogomils, annales, niccol, morton, colloquial,
# Nearest to at: michaux, awry, pinky, insights, nineveh,
# Nearest to first: synopsis, qualities, ursa, eliot, andronicus,
# Nearest to can: genosha, multiculturalism, ferrite, ranch, deified,
# Nearest to will: gotland, downfall, depictions, indira, converted,
# Nearest to eight: intentionality, arthropods, dictates, tonight, methods,
# Nearest to only: scene, ruiz, cunning, ethology, livery,
# Nearest to he: christensen, trilobite, raphaelite, mental, histone,
# Nearest to some: prefectures, environmentalist, moe, ailey, thing,
# Nearest to that: sharps, rv, students, sharpness, aspartame,
# Nearest to six: mulholland, nellis, smells, lichens, accommodating,
# Nearest to its: tragedies, dickens, neuch, deterrent, dunwich,
# Nearest to one: soma, avatar, worker, michaels, permafrost,
# Nearest to world: chromatic, expansionism, lemmings, naturally, talented,
# Nearest to has: dtd, middletown, pentecost, opportunistic, commandment,
# Nearest to if: yastrzemski, sinful, impairment, hindu, horne,
# Nearest to of: chats, assessing, ensured, psc, satr,
# Nearest to people: brainstem, petrels, lille, reared, marlins,
# Average loss at step 100: 0.590646
# Average loss at step 200: 0.442884
# Average loss at step 300: 0.328288
# Average loss at step 400: 0.350696
# Average loss at step 500: 0.315266
# Average loss at step 600: 0.289776
# Average loss at step 700: 0.266378
# Average loss at step 800: 0.255301
# Average loss at step 900: 0.237098
# Average loss at step 1000: 0.214624
# Nearest to however: solzhenitsyn, power, immobile, ferrous, sinhalese,
# Nearest to these: ct, refurbishment, purer, delicacies, UNK,
# Nearest to nine: one, zero, four, six, in,
# Nearest to at: and, the, two, to, of,
# Nearest to first: offshoots, qualities, ursa, prehistoric, of,
# Nearest to can: genosha, deified, as, multiculturalism, ranch,
# Nearest to will: gotland, downfall, sydney, serotonin, seventy,
# Nearest to eight: one, UNK, two, a, and,
# Nearest to only: in, by, or, plasmas, but,
# Nearest to he: a, christensen, and, the, of,
# Nearest to some: many, moe, s, this, a,
# Nearest to that: the, in, to, of, and,
# Nearest to six: of, the, and, two, one,
# Nearest to its: a, and, germany, the, them,
# Nearest to one: of, in, the, to, UNK,
# Nearest to world: chromatic, a, play, naturally, examiners,
# Nearest to has: in, was, is, that, also,
# Nearest to if: horne, hindu, sinful, eno, of,
# Nearest to of: the, in, and, UNK, to,
# Nearest to people: brainstem, lille, courtier, idea, contrasts,
# Average loss at step 1100: 0.187916
# Average loss at step 1200: 0.173336
# Average loss at step 1300: 0.190253
# Average loss at step 1400: 0.176570
# Average loss at step 1500: 0.157997
# Average loss at step 1600: 0.165017
# Average loss at step 1700: 0.155862
# Average loss at step 1800: 0.149741
# Average loss at step 1900: 0.138551
# Average loss at step 2000: 0.131872
# Nearest to however: power, two, as, immobile, or,
# Nearest to these: UNK, in, the, and, a,
# Nearest to nine: one, zero, two, four, six,
# Nearest to at: and, to, two, a, the,
# Nearest to first: on, of, as, that, is,
# Nearest to can: as, for, a, is, this,
# Nearest to will: downfall, german, gotland, a, his,
# Nearest to eight: one, two, UNK, a, and,
# Nearest to only: by, but, or, in, this,
# Nearest to he: a, and, that, UNK, is,
# Nearest to some: s, this, a, many, UNK,
# Nearest to that: the, in, a, to, of,
# Nearest to six: of, two, the, one, and,
# Nearest to its: a, and, s, is, the,
# Nearest to one: in, of, UNK, to, and,
# Nearest to world: a, its, have, two, this,
# Nearest to has: was, is, in, that, by,
# Nearest to if: is, of, on, in, and,
# Nearest to of: the, and, in, UNK, to,
# Nearest to people: a, their, were, idea, in,
# Average loss at step 2100: 0.140223
# Average loss at step 2200: 0.132869
# Average loss at step 2300: 0.128049
# Average loss at step 2400: 0.135578
# Average loss at step 2500: 0.116338
# Average loss at step 2600: 0.107058
# Average loss at step 2700: 0.115935
# Average loss at step 2800: 0.111271
# Average loss at step 2900: 0.109829
# Average loss at step 3000: 0.109366
# Nearest to however: two, as, power, at, from,
# Nearest to these: UNK, in, the, a, are,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: and, a, to, of, in,
# Nearest to first: on, as, that, of, is,
# Nearest to can: as, for, this, a, is,
# Nearest to will: a, to, have, his, or,
# Nearest to eight: one, two, UNK, a, by,
# Nearest to only: by, this, or, but, in,
# Nearest to he: a, is, that, was, on,
# Nearest to some: s, this, a, UNK, many,
# Nearest to that: in, the, a, of, to,
# Nearest to six: of, two, one, or, four,
# Nearest to its: a, s, is, his, and,
# Nearest to one: in, of, UNK, to, and,
# Nearest to world: its, a, some, have, this,
# Nearest to has: was, is, that, by, on,
# Nearest to if: is, on, in, of, and,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, a, also, into,
# Average loss at step 3100: 0.101786
# Average loss at step 3200: 0.101242
# Average loss at step 3300: 0.097244
# Average loss at step 3400: 0.089142
# Average loss at step 3500: 0.090494
# Average loss at step 3600: 0.088858
# Average loss at step 3700: 0.085951
# Average loss at step 3800: 0.086025
# Average loss at step 3900: 0.082408
# Average loss at step 4000: 0.083986
# Nearest to however: two, as, at, from, this,
# Nearest to these: UNK, in, are, it, a,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: and, a, to, in, of,
# Nearest to first: on, as, from, that, with,
# Nearest to can: as, for, this, a, is,
# Nearest to will: a, his, have, to, or,
# Nearest to eight: one, two, UNK, by, a,
# Nearest to only: by, this, but, or, in,
# Nearest to he: a, was, that, is, on,
# Nearest to some: s, this, a, as, UNK,
# Nearest to that: in, the, a, of, to,
# Nearest to six: of, two, or, four, one,
# Nearest to its: a, s, is, his, which,
# Nearest to one: in, of, UNK, to, a,
# Nearest to world: its, a, some, have, this,
# Nearest to has: was, is, that, by, on,
# Nearest to if: on, is, in, of, have,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, a,
# Average loss at step 4100: 0.083417
# Average loss at step 4200: 0.084586
# Average loss at step 4300: 0.083779
# Average loss at step 4400: 0.072797
# Average loss at step 4500: 0.075913
# Average loss at step 4600: 0.075542
# Average loss at step 4700: 0.074472
# Average loss at step 4800: 0.068066
# Average loss at step 4900: 0.066863
# Average loss at step 5000: 0.074801
# Nearest to however: two, as, at, from, this,
# Nearest to these: UNK, are, in, it, a,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: a, and, in, to, as,
# Nearest to first: on, as, from, that, with,
# Nearest to can: as, for, this, from, a,
# Nearest to will: a, have, his, to, or,
# Nearest to eight: one, two, by, UNK, a,
# Nearest to only: by, this, but, or, on,
# Nearest to he: was, a, that, is, on,
# Nearest to some: s, this, a, as, many,
# Nearest to that: in, a, the, of, to,
# Nearest to six: or, two, four, one, of,
# Nearest to its: a, s, is, which, his,
# Nearest to one: in, of, UNK, a, to,
# Nearest to world: its, some, have, this, but,
# Nearest to has: was, is, that, on, by,
# Nearest to if: on, is, in, with, have,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 5100: 0.070166
# Average loss at step 5200: 0.072664
# Average loss at step 5300: 0.062979
# Average loss at step 5400: 0.073254
# Average loss at step 5500: 0.068627
# Average loss at step 5600: 0.065269
# Average loss at step 5700: 0.060438
# Average loss at step 5800: 0.066437
# Average loss at step 5900: 0.064554
# Average loss at step 6000: 0.067856
# Nearest to however: two, at, as, from, this,
# Nearest to these: UNK, are, in, it, a,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: a, and, as, in, was,
# Nearest to first: on, as, from, that, with,
# Nearest to can: as, for, this, from, is,
# Nearest to will: have, his, a, or, from,
# Nearest to eight: one, two, by, UNK, a,
# Nearest to only: but, this, by, or, on,
# Nearest to he: was, that, on, a, is,
# Nearest to some: s, this, a, as, by,
# Nearest to that: in, a, the, of, as,
# Nearest to six: or, two, four, one, of,
# Nearest to its: a, s, is, his, which,
# Nearest to one: in, of, UNK, a, to,
# Nearest to world: its, have, some, but, an,
# Nearest to has: was, is, on, that, by,
# Nearest to if: on, is, have, this, with,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 6100: 0.066987
# Average loss at step 6200: 0.065888
# Average loss at step 6300: 0.057827
# Average loss at step 6400: 0.065609
# Average loss at step 6500: 0.056943
# Average loss at step 6600: 0.057893
# Average loss at step 6700: 0.060982
# Average loss at step 6800: 0.051652
# Average loss at step 6900: 0.048106
# Average loss at step 7000: 0.055357
# Nearest to however: two, at, from, as, this,
# Nearest to these: are, UNK, in, it, a,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: a, as, and, that, was,
# Nearest to first: on, as, from, with, that,
# Nearest to can: as, for, this, from, is,
# Nearest to will: have, his, or, from, a,
# Nearest to eight: one, two, by, four, UNK,
# Nearest to only: but, this, by, or, on,
# Nearest to he: was, that, on, is, a,
# Nearest to some: s, this, a, as, by,
# Nearest to that: in, a, the, as, of,
# Nearest to six: or, two, four, one, on,
# Nearest to its: a, s, is, which, on,
# Nearest to one: in, of, UNK, a, to,
# Nearest to world: its, have, some, but, an,
# Nearest to has: was, is, on, that, by,
# Nearest to if: on, is, have, this, with,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 7100: 0.057583
# Average loss at step 7200: 0.053140
# Average loss at step 7300: 0.053164
# Average loss at step 7400: 0.055465
# Average loss at step 7500: 0.055801
# Average loss at step 7600: 0.060920
# Average loss at step 7700: 0.052915
# Average loss at step 7800: 0.042941
# Average loss at step 7900: 0.047204
# Average loss at step 8000: 0.056714
# Nearest to however: two, at, from, this, as,
# Nearest to these: are, UNK, in, it, a,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: a, as, that, was, in,
# Nearest to first: on, as, from, that, with,
# Nearest to can: as, for, this, from, an,
# Nearest to will: have, his, from, or, a,
# Nearest to eight: one, two, by, an, four,
# Nearest to only: but, this, by, or, on,
# Nearest to he: that, on, was, are, from,
# Nearest to some: s, this, a, as, by,
# Nearest to that: in, a, as, the, of,
# Nearest to six: or, two, four, one, on,
# Nearest to its: a, s, is, which, on,
# Nearest to one: in, of, UNK, a, to,
# Nearest to world: its, have, some, but, an,
# Nearest to has: was, is, on, that, by,
# Nearest to if: on, is, have, this, with,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 8100: 0.045844
# Average loss at step 8200: 0.048799
# Average loss at step 8300: 0.050781
# Average loss at step 8400: 0.052748
# Average loss at step 8500: 0.050083
# Average loss at step 8600: 0.044684
# Average loss at step 8700: 0.046475
# Average loss at step 8800: 0.045568
# Average loss at step 8900: 0.050982
# Average loss at step 9000: 0.038877
# Nearest to however: two, this, from, at, as,
# Nearest to these: are, UNK, it, in, by,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: a, as, that, was, in,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, for, this, from, an,
# Nearest to will: have, his, from, or, a,
# Nearest to eight: one, two, by, an, four,
# Nearest to only: this, but, by, or, on,
# Nearest to he: that, on, was, are, from,
# Nearest to some: this, s, as, a, by,
# Nearest to that: in, a, as, the, of,
# Nearest to six: or, two, four, one, on,
# Nearest to its: a, s, is, which, on,
# Nearest to one: in, of, UNK, a, to,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, by,
# Nearest to if: on, is, this, have, with,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, most,
# Average loss at step 9100: 0.042182
# Average loss at step 9200: 0.052200
# Average loss at step 9300: 0.047323
# Average loss at step 9400: 0.044382
# Average loss at step 9500: 0.043618
# Average loss at step 9600: 0.042895
# Average loss at step 9700: 0.040894
# Average loss at step 9800: 0.041490
# Average loss at step 9900: 0.041729
# Average loss at step 10000: 0.042185
# Nearest to however: two, this, at, from, as,
# Nearest to these: are, UNK, it, in, was,
# Nearest to nine: one, four, two, zero, six,
# Nearest to at: a, as, two, was, that,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, a,
# Nearest to eight: one, two, by, four, an,
# Nearest to only: but, this, by, or, on,
# Nearest to he: that, on, was, are, from,
# Nearest to some: this, s, as, a, at,
# Nearest to that: in, a, as, the, of,
# Nearest to six: two, or, four, one, on,
# Nearest to its: a, s, is, which, his,
# Nearest to one: in, of, UNK, a, to,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, by,
# Nearest to if: on, is, this, have, with,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 10100: 0.038862
# Average loss at step 10200: 0.039165
# Average loss at step 10300: 0.043550
# Average loss at step 10400: 0.040961
# Average loss at step 10500: 0.041944
# Average loss at step 10600: 0.041192
# Average loss at step 10700: 0.043138
# Average loss at step 10800: 0.041948
# Average loss at step 10900: 0.038365
# Average loss at step 11000: 0.037633
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, UNK, it, in, was,
# Nearest to nine: one, four, two, six, zero,
# Nearest to at: a, as, was, one, that,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: one, two, by, four, an,
# Nearest to only: but, this, by, or, on,
# Nearest to he: was, that, on, is, from,
# Nearest to some: this, s, as, at, a,
# Nearest to that: in, a, as, the, of,
# Nearest to six: two, or, four, one, on,
# Nearest to its: a, his, s, which, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 11100: 0.033202
# Average loss at step 11200: 0.042648
# Average loss at step 11300: 0.040249
# Average loss at step 11400: 0.042933
# Average loss at step 11500: 0.034371
# Average loss at step 11600: 0.041213
# Average loss at step 11700: 0.037525
# Average loss at step 11800: 0.036788
# Average loss at step 11900: 0.043235
# Average loss at step 12000: 0.041646
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, UNK, in, was,
# Nearest to nine: one, four, two, six, zero,
# Nearest to at: a, as, was, one, that,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: one, two, by, four, an,
# Nearest to only: but, this, by, or, on,
# Nearest to he: was, that, on, from, is,
# Nearest to some: this, s, as, at, a,
# Nearest to that: in, a, as, the, of,
# Nearest to six: two, four, or, one, on,
# Nearest to its: a, his, s, is, which,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 12100: 0.038668
# Average loss at step 12200: 0.040584
# Average loss at step 12300: 0.045202
# Average loss at step 12400: 0.040234
# Average loss at step 12500: 0.044512
# Average loss at step 12600: 0.036309
# Average loss at step 12700: 0.038653
# Average loss at step 12800: 0.037263
# Average loss at step 12900: 0.039380
# Average loss at step 13000: 0.038438
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, UNK, in, was,
# Nearest to nine: one, four, two, six, zero,
# Nearest to at: a, as, was, that, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: two, one, by, four, an,
# Nearest to only: but, this, by, or, on,
# Nearest to he: was, on, that, from, is,
# Nearest to some: this, s, as, at, by,
# Nearest to that: in, a, as, the, of,
# Nearest to six: or, two, four, one, on,
# Nearest to its: a, his, s, which, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, he,
# Average loss at step 13100: 0.034772
# Average loss at step 13200: 0.035701
# Average loss at step 13300: 0.032869
# Average loss at step 13400: 0.031063
# Average loss at step 13500: 0.028800
# Average loss at step 13600: 0.032135
# Average loss at step 13700: 0.031934
# Average loss at step 13800: 0.034898
# Average loss at step 13900: 0.035020
# Average loss at step 14000: 0.042417
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, UNK, in,
# Nearest to nine: one, four, two, six, zero,
# Nearest to at: a, as, was, with, that,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: two, one, by, four, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: was, on, that, from, is,
# Nearest to some: this, s, as, at, by,
# Nearest to that: in, as, a, by, the,
# Nearest to six: or, two, four, one, on,
# Nearest to its: a, his, s, which, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 14100: 0.034757
# Average loss at step 14200: 0.034009
# Average loss at step 14300: 0.042040
# Average loss at step 14400: 0.041586
# Average loss at step 14500: 0.033291
# Average loss at step 14600: 0.043840
# Average loss at step 14700: 0.035740
# Average loss at step 14800: 0.034183
# Average loss at step 14900: 0.037336
# Average loss at step 15000: 0.036089
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, in, was, by,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: a, as, was, with, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: two, one, by, four, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: that, was, on, from, are,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, the,
# Nearest to six: four, or, two, one, on,
# Nearest to its: a, his, s, which, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: the, and, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 15100: 0.040695
# Average loss at step 15200: 0.032790
# Average loss at step 15300: 0.036920
# Average loss at step 15400: 0.035138
# Average loss at step 15500: 0.036663
# Average loss at step 15600: 0.035389
# Average loss at step 15700: 0.030985
# Average loss at step 15800: 0.034593
# Average loss at step 15900: 0.034205
# Average loss at step 16000: 0.030382
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, in, by,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: a, as, was, with, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: two, one, by, four, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: that, on, was, from, are,
# Nearest to some: this, s, at, as, many,
# Nearest to that: in, as, a, by, the,
# Nearest to six: four, or, two, one, on,
# Nearest to its: a, his, which, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, but, have, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 16100: 0.032245
# Average loss at step 16200: 0.023278
# Average loss at step 16300: 0.027252
# Average loss at step 16400: 0.029626
# Average loss at step 16500: 0.022476
# Average loss at step 16600: 0.026388
# Average loss at step 16700: 0.031388
# Average loss at step 16800: 0.031665
# Average loss at step 16900: 0.027513
# Average loss at step 17000: 0.028766
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, in,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: a, as, was, with, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: two, one, by, four, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: on, from, that, was, are,
# Nearest to some: this, s, at, as, many,
# Nearest to that: in, as, a, by, the,
# Nearest to six: four, or, two, one, on,
# Nearest to its: a, his, which, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, but, have, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, is, this, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 17100: 0.028719
# Average loss at step 17200: 0.031720
# Average loss at step 17300: 0.029135
# Average loss at step 17400: 0.029772
# Average loss at step 17500: 0.027259
# Average loss at step 17600: 0.028035
# Average loss at step 17700: 0.031909
# Average loss at step 17800: 0.029231
# Average loss at step 17900: 0.024568
# Average loss at step 18000: 0.030856
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, in,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: a, as, was, two, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: his, have, from, or, which,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, on, that, was, are,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, the,
# Nearest to six: four, or, two, one, on,
# Nearest to its: a, which, his, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, have, but, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 18100: 0.030313
# Average loss at step 18200: 0.031309
# Average loss at step 18300: 0.032599
# Average loss at step 18400: 0.028660
# Average loss at step 18500: 0.028365
# Average loss at step 18600: 0.030234
# Average loss at step 18700: 0.029408
# Average loss at step 18800: 0.026641
# Average loss at step 18900: 0.031109
# Average loss at step 19000: 0.024686
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, was, by, in,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, one, two,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: have, his, from, or, which,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, that, on, was, are,
# Nearest to some: this, s, at, as, many,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, a, his, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, but, have, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 19100: 0.024313
# Average loss at step 19200: 0.030474
# Average loss at step 19300: 0.023440
# Average loss at step 19400: 0.026184
# Average loss at step 19500: 0.028116
# Average loss at step 19600: 0.027917
# Average loss at step 19700: 0.027856
# Average loss at step 19800: 0.027120
# Average loss at step 19900: 0.028536
# Average loss at step 20000: 0.028916
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, in,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, one, two,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: have, his, from, or, which,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, that, on, was, are,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, a, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, but, have, some, an,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 20100: 0.030126
# Average loss at step 20200: 0.036466
# Average loss at step 20300: 0.025414
# Average loss at step 20400: 0.027618
# Average loss at step 20500: 0.026232
# Average loss at step 20600: 0.022724
# Average loss at step 20700: 0.024461
# Average loss at step 20800: 0.027633
# Average loss at step 20900: 0.026664
# Average loss at step 21000: 0.024938
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, in,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, one, with,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: have, his, from, or, which,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, on, that, was, are,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, a, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 21100: 0.024159
# Average loss at step 21200: 0.022069
# Average loss at step 21300: 0.028020
# Average loss at step 21400: 0.023458
# Average loss at step 21500: 0.027805
# Average loss at step 21600: 0.026276
# Average loss at step 21700: 0.027488
# Average loss at step 21800: 0.024494
# Average loss at step 21900: 0.025227
# Average loss at step 22000: 0.018693
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, was, by, from,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, one, with,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: his, which, a, s, is,
# Nearest to one: in, of, UNK, a, and,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 22100: 0.026672
# Average loss at step 22200: 0.020699
# Average loss at step 22300: 0.022135
# Average loss at step 22400: 0.025882
# Average loss at step 22500: 0.026170
# Average loss at step 22600: 0.025439
# Average loss at step 22700: 0.022165
# Average loss at step 22800: 0.019264
# Average loss at step 22900: 0.029138
# Average loss at step 23000: 0.018391
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, was, by, from,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, for, from, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, a, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, is, on, that, also,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 23100: 0.022184
# Average loss at step 23200: 0.020682
# Average loss at step 23300: 0.021245
# Average loss at step 23400: 0.022800
# Average loss at step 23500: 0.026525
# Average loss at step 23600: 0.023624
# Average loss at step 23700: 0.021659
# Average loss at step 23800: 0.020529
# Average loss at step 23900: 0.023115
# Average loss at step 24000: 0.019410
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, was, by, from,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, or, who,
# Nearest to he: from, on, that, was, are,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: his, which, a, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 24100: 0.024730
# Average loss at step 24200: 0.022048
# Average loss at step 24300: 0.021207
# Average loss at step 24400: 0.025278
# Average loss at step 24500: 0.023764
# Average loss at step 24600: 0.021910
# Average loss at step 24700: 0.024507
# Average loss at step 24800: 0.022222
# Average loss at step 24900: 0.024651
# Average loss at step 25000: 0.024485
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, from,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, by, who, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, a, s, on,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, is, on, that, also,
# Nearest to if: on, this, is, have, which,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 25100: 0.019693
# Average loss at step 25200: 0.019568
# Average loss at step 25300: 0.025745
# Average loss at step 25400: 0.023356
# Average loss at step 25500: 0.022368
# Average loss at step 25600: 0.021156
# Average loss at step 25700: 0.022497
# Average loss at step 25800: 0.025091
# Average loss at step 25900: 0.017992
# Average loss at step 26000: 0.018705
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, from,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, with,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, a, s, on,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, is, on, that, also,
# Nearest to if: on, this, is, which, have,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 26100: 0.023094
# Average loss at step 26200: 0.024408
# Average loss at step 26300: 0.020962
# Average loss at step 26400: 0.022045
# Average loss at step 26500: 0.024546
# Average loss at step 26600: 0.019515
# Average loss at step 26700: 0.018147
# Average loss at step 26800: 0.017729
# Average loss at step 26900: 0.020340
# Average loss at step 27000: 0.025034
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, by, from,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, a, s, on,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, is, on, that, or,
# Nearest to if: on, this, is, which, have,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 27100: 0.019876
# Average loss at step 27200: 0.021393
# Average loss at step 27300: 0.021282
# Average loss at step 27400: 0.021236
# Average loss at step 27500: 0.019936
# Average loss at step 27600: 0.019625
# Average loss at step 27700: 0.020291
# Average loss at step 27800: 0.019801
# Average loss at step 27900: 0.022397
# Average loss at step 28000: 0.017837
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, from, by,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, a, s, on,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, is, on, that, also,
# Nearest to if: on, this, is, which, have,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 28100: 0.022475
# Average loss at step 28200: 0.020280
# Average loss at step 28300: 0.019701
# Average loss at step 28400: 0.018535
# Average loss at step 28500: 0.017712
# Average loss at step 28600: 0.021430
# Average loss at step 28700: 0.019049
# Average loss at step 28800: 0.020276
# Average loss at step 28900: 0.020763
# Average loss at step 29000: 0.016062
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, from, by,
# Nearest to nine: four, one, two, six, zero,
# Nearest to at: as, a, was, two, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, a, s, on,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, is, on, that, also,
# Nearest to if: on, this, is, which, have,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 29100: 0.022224
# Average loss at step 29200: 0.023316
# Average loss at step 29300: 0.022125
# Average loss at step 29400: 0.017754
# Average loss at step 29500: 0.020541
# Average loss at step 29600: 0.020870
# Average loss at step 29700: 0.020703
# Average loss at step 29800: 0.020077
# Average loss at step 29900: 0.019843
# Average loss at step 30000: 0.022060
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, from, by,
# Nearest to nine: four, one, six, two, zero,
# Nearest to at: as, a, was, one, with,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, or, two, one, on,
# Nearest to its: which, his, on, a, s,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, is, have,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 30100: 0.016896
# Average loss at step 30200: 0.020762
# Average loss at step 30300: 0.015595
# Average loss at step 30400: 0.020278
# Average loss at step 30500: 0.016840
# Average loss at step 30600: 0.017874
# Average loss at step 30700: 0.018239
# Average loss at step 30800: 0.020424
# Average loss at step 30900: 0.017366
# Average loss at step 31000: 0.019702
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, was, from, by,
# Nearest to nine: four, one, six, two, zero,
# Nearest to at: as, a, was, with, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, that, are, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, a,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, is, have,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 31100: 0.017258
# Average loss at step 31200: 0.019551
# Average loss at step 31300: 0.014479
# Average loss at step 31400: 0.016192
# Average loss at step 31500: 0.018408
# Average loss at step 31600: 0.025111
# Average loss at step 31700: 0.020000
# Average loss at step 31800: 0.018107
# Average loss at step 31900: 0.019049
# Average loss at step 32000: 0.017895
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, one, six, two, zero,
# Nearest to at: as, a, was, two, with,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, are, that, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, a,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 32100: 0.017663
# Average loss at step 32200: 0.021103
# Average loss at step 32300: 0.015150
# Average loss at step 32400: 0.016638
# Average loss at step 32500: 0.019747
# Average loss at step 32600: 0.020179
# Average loss at step 32700: 0.018657
# Average loss at step 32800: 0.015284
# Average loss at step 32900: 0.018465
# Average loss at step 33000: 0.014980
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, one, two, zero,
# Nearest to at: as, was, a, two, with,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, or,
# Nearest to eight: two, one, four, by, an,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, on, are, that, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, a,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 33100: 0.020154
# Average loss at step 33200: 0.018860
# Average loss at step 33300: 0.019050
# Average loss at step 33400: 0.020561
# Average loss at step 33500: 0.028650
# Average loss at step 33600: 0.017891
# Average loss at step 33700: 0.020685
# Average loss at step 33800: 0.019738
# Average loss at step 33900: 0.017551
# Average loss at step 34000: 0.022449
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, one, two, zero,
# Nearest to at: as, was, a, two, with,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, five,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, are, on, that, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 34100: 0.019167
# Average loss at step 34200: 0.019278
# Average loss at step 34300: 0.020852
# Average loss at step 34400: 0.018853
# Average loss at step 34500: 0.018187
# Average loss at step 34600: 0.019062
# Average loss at step 34700: 0.019378
# Average loss at step 34800: 0.021007
# Average loss at step 34900: 0.017832
# Average loss at step 35000: 0.018147
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, with,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, five,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, are, on, that, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 35100: 0.015460
# Average loss at step 35200: 0.015699
# Average loss at step 35300: 0.016925
# Average loss at step 35400: 0.015520
# Average loss at step 35500: 0.014010
# Average loss at step 35600: 0.014603
# Average loss at step 35700: 0.015558
# Average loss at step 35800: 0.020009
# Average loss at step 35900: 0.018059
# Average loss at step 36000: 0.018517
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, with,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, five,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, are, on, that, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 36100: 0.018475
# Average loss at step 36200: 0.021588
# Average loss at step 36300: 0.014949
# Average loss at step 36400: 0.014875
# Average loss at step 36500: 0.014875
# Average loss at step 36600: 0.016750
# Average loss at step 36700: 0.017680
# Average loss at step 36800: 0.016968
# Average loss at step 36900: 0.016737
# Average loss at step 37000: 0.018217
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, five,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, are, on, that, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 37100: 0.016498
# Average loss at step 37200: 0.015978
# Average loss at step 37300: 0.014157
# Average loss at step 37400: 0.016194
# Average loss at step 37500: 0.018755
# Average loss at step 37600: 0.017340
# Average loss at step 37700: 0.016091
# Average loss at step 37800: 0.015994
# Average loss at step 37900: 0.016487
# Average loss at step 38000: 0.021771
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, or,
# Nearest to eight: two, one, four, by, five,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: in, as, a, by, was,
# Nearest to six: four, two, or, one, on,
# Nearest to its: which, his, on, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 38100: 0.015020
# Average loss at step 38200: 0.018234
# Average loss at step 38300: 0.014425
# Average loss at step 38400: 0.016668
# Average loss at step 38500: 0.016778
# Average loss at step 38600: 0.015449
# Average loss at step 38700: 0.015329
# Average loss at step 38800: 0.017176
# Average loss at step 38900: 0.017159
# Average loss at step 39000: 0.017773
# Nearest to however: two, this, at, from, he,
# Nearest to these: are, it, from, was, by,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, one,
# Nearest to first: on, from, as, that, three,
# Nearest to can: as, this, from, for, an,
# Nearest to will: have, his, from, which, or,
# Nearest to eight: two, one, four, by, five,
# Nearest to only: but, this, who, by, or,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, s, at, as, by,
# Nearest to that: as, in, a, by, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, s, is,
# Nearest to one: in, of, UNK, a, is,
# Nearest to world: its, have, but, some, into,
# Nearest to has: was, on, is, that, also,
# Nearest to if: on, this, which, have, is,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, were, into, also, three,
# Average loss at step 39100: 0.012916
# Average loss at step 39200: 0.013189
# Average loss at step 39300: 0.014875
# ...
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 87100: 0.005837
# Average loss at step 87200: 0.006784
# Average loss at step 87300: 0.008276
# Average loss at step 87400: 0.007600
# Average loss at step 87500: 0.006586
# Average loss at step 87600: 0.008502
# Average loss at step 87700: 0.006428
# Average loss at step 87800: 0.007092
# Average loss at step 87900: 0.009369
# Average loss at step 88000: 0.007118
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, in,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, one, four, five, by,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 88100: 0.024509
# Average loss at step 88200: 0.006837
# Average loss at step 88300: 0.007317
# Average loss at step 88400: 0.007129
# Average loss at step 88500: 0.009721
# Average loss at step 88600: 0.006417
# Average loss at step 88700: 0.006607
# Average loss at step 88800: 0.006666
# Average loss at step 88900: 0.007183
# Average loss at step 89000: 0.006663
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, two, in,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 89100: 0.006706
# Average loss at step 89200: 0.005820
# Average loss at step 89300: 0.005390
# Average loss at step 89400: 0.006040
# Average loss at step 89500: 0.006625
# Average loss at step 89600: 0.004595
# Average loss at step 89700: 0.005017
# Average loss at step 89800: 0.006666
# Average loss at step 89900: 0.006615
# Average loss at step 90000: 0.006061
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 90100: 0.005232
# Average loss at step 90200: 0.007510
# Average loss at step 90300: 0.006812
# Average loss at step 90400: 0.007361
# Average loss at step 90500: 0.006549
# Average loss at step 90600: 0.006708
# Average loss at step 90700: 0.006408
# Average loss at step 90800: 0.008551
# Average loss at step 90900: 0.007402
# Average loss at step 91000: 0.007920
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 91100: 0.007772
# Average loss at step 91200: 0.005915
# Average loss at step 91300: 0.007120
# Average loss at step 91400: 0.007650
# Average loss at step 91500: 0.007043
# Average loss at step 91600: 0.007528
# Average loss at step 91700: 0.007264
# Average loss at step 91800: 0.005512
# Average loss at step 91900: 0.008341
# Average loss at step 92000: 0.004438
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 92100: 0.006130
# Average loss at step 92200: 0.006938
# Average loss at step 92300: 0.006392
# Average loss at step 92400: 0.007059
# Average loss at step 92500: 0.007849
# Average loss at step 92600: 0.005752
# Average loss at step 92700: 0.006409
# Average loss at step 92800: 0.006644
# Average loss at step 92900: 0.007037
# Average loss at step 93000: 0.004649
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 93100: 0.006144
# Average loss at step 93200: 0.005600
# Average loss at step 93300: 0.005498
# Average loss at step 93400: 0.005062
# Average loss at step 93500: 0.006202
# Average loss at step 93600: 0.007497
# Average loss at step 93700: 0.006369
# Average loss at step 93800: 0.006186
# Average loss at step 93900: 0.005832
# Average loss at step 94000: 0.007122
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, UNK, is, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 94100: 0.006353
# Average loss at step 94200: 0.006918
# Average loss at step 94300: 0.006400
# Average loss at step 94400: 0.006380
# Average loss at step 94500: 0.007065
# Average loss at step 94600: 0.006810
# Average loss at step 94700: 0.006815
# Average loss at step 94800: 0.006839
# Average loss at step 94900: 0.005818
# Average loss at step 95000: 0.007441
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, is, UNK, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 95100: 0.004972
# Average loss at step 95200: 0.005959
# Average loss at step 95300: 0.005831
# Average loss at step 95400: 0.004801
# Average loss at step 95500: 0.004696
# Average loss at step 95600: 0.005409
# Average loss at step 95700: 0.006189
# Average loss at step 95800: 0.005116
# Average loss at step 95900: 0.006380
# Average loss at step 96000: 0.006812
# Nearest to however: two, this, from, at, he,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, five,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, is, UNK, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 96100: 0.005975
# Average loss at step 96200: 0.006852
# Average loss at step 96300: 0.006280
# Average loss at step 96400: 0.004761
# Average loss at step 96500: 0.006114
# Average loss at step 96600: 0.007237
# Average loss at step 96700: 0.005662
# Average loss at step 96800: 0.006815
# Average loss at step 96900: 0.005872
# Average loss at step 97000: 0.006855
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, zero,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, is, UNK, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 97100: 0.004842
# Average loss at step 97200: 0.005243
# Average loss at step 97300: 0.005254
# Average loss at step 97400: 0.005315
# Average loss at step 97500: 0.005984
# Average loss at step 97600: 0.004718
# Average loss at step 97700: 0.004900
# Average loss at step 97800: 0.006060
# Average loss at step 97900: 0.004959
# Average loss at step 98000: 0.005956
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, five,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, is, UNK, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 98100: 0.005471
# Average loss at step 98200: 0.005234
# Average loss at step 98300: 0.007677
# Average loss at step 98400: 0.005700
# Average loss at step 98500: 0.005658
# Average loss at step 98600: 0.006077
# Average loss at step 98700: 0.005570
# Average loss at step 98800: 0.005355
# Average loss at step 98900: 0.005793
# Average loss at step 99000: 0.006728
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, five,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, from,
# Nearest to one: in, of, is, UNK, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
# Average loss at step 99100: 0.005426
# Average loss at step 99200: 0.006305
# Average loss at step 99300: 0.006294
# Average loss at step 99400: 0.005666
# Average loss at step 99500: 0.005670
# Average loss at step 99600: 0.005449
# Average loss at step 99700: 0.005857
# Average loss at step 99800: 0.006168
# Average loss at step 99900: 0.006924
# Average loss at step 100000: 0.006073
# Nearest to however: two, this, from, at, four,
# Nearest to these: are, it, from, at, was,
# Nearest to nine: four, six, two, one, five,
# Nearest to at: as, was, a, in, two,
# Nearest to first: from, on, three, that, as,
# Nearest to can: as, this, from, for, an,
# Nearest to will: his, have, from, which, its,
# Nearest to eight: two, four, one, five, zero,
# Nearest to only: but, this, who, most, by,
# Nearest to he: from, are, that, on, was,
# Nearest to some: this, at, s, as, by,
# Nearest to that: as, in, by, a, was,
# Nearest to six: four, two, or, on, one,
# Nearest to its: which, his, on, is, it,
# Nearest to one: in, of, is, UNK, a,
# Nearest to world: its, but, have, some, into,
# Nearest to has: was, also, on, is, that,
# Nearest to if: on, this, have, which, some,
# Nearest to of: and, the, in, UNK, a,
# Nearest to people: their, into, were, also, three,
